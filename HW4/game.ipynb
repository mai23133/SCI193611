# %% [markdown]
# # HW4 — เกม Hexapawn ด้วย Alpha-Beta
#
# งานนี้สร้างเกม Hexapawn ขนาด 3×3 โดยให้ AI เลือกตาเดินด้วยอัลกอริทึม Alpha-Beta Pruning

# %%
from game import Hexapawn, alpha_beta_player, format_move, launch_gui

game = Hexapawn()
state = game.initial
game.display(state)
# Out:
#   a b c
# 3 B B B
# 2 . . .
# 1 W W W

# %% [markdown]
# ## การเลือกตาเดินของ AI
# โค้ดด้านล่างทดสอบให้ AI คำนวณและแสดงตาเดินที่เหมาะสมที่สุดจากกระดานเริ่มต้น

# %%
move = alpha_beta_player(game, state)
print('Alpha-Beta chooses:', format_move(move))
state = game.result(state, move)
game.display(state)
# Out:
# Alpha-Beta chooses: a1 a2
#   a b c
# 3 B B B
# 2 W . .
# 1 . W W

# %% [markdown]
# ## เล่นเกมกับ AI

# %%
launch_gui()
